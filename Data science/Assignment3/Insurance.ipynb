# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance-data.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df[df['charges']==df['charges'].max()]
# Out:
#      age     sex    bmi  children smoker     region      charges
# 543   54  female  47.41         0    yes  southeast  63770.42801

# %%
sns.countplot(data = df, x = 'sex')
print(df.sex.value_counts())
#Conclusion : Number of males and females are roughly the same
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
#to find the otliers acorrding to charges:
sns.boxplot(x='charges', data=df, color='red').set(title='charges outliers')
# Out:
# [Text(0.5, 1.0, 'charges outliers')]

# %%
#Getting insights about the weird outlier
df[df['charges']==df['charges'].max()]
# Out:
#      age     sex    bmi  children smoker     region      charges
# 543   54  female  47.41         0    yes  southeast  63770.42801

# %%
sns.scatterplot(data=df,x='bmi',y='charges',hue='sex')

# %%
sns.countplot(data=df,x='region',hue='smoker')
#Conclusion : mostly are non smokers (The most smokers are in southeast)

# %%
sns.countplot(data=df,x='sex',hue='smoker')

# %%
sns.scatterplot(data=df,x='age',y='charges',hue='sex')

# %%
sns.barplot(data=df,y='charges',x='smoker')
#Conclusion : Smokers mostly pays more than non-smokers

# %%
sns.barplot(data=df,y='charges',x='region')
#Conclusion :Charges are more in southeast than other regions

# %%
sns.barplot(data=df,y='bmi',x='smoker')

# %%
sns.barplot(data = df , y = 'charges' , x= 'children' )
#Conclusion : mostly people with 2 or 3 children have higher charges than other

# %%
#Visualizing the correlation between the features:
sns.heatmap(df.corr())
